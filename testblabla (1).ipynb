# %% [markdown]
# # Welcome to Jupyter!

# %%
import pandas

# %%
table = pandas.read_csv('http://webstat.banque-france.fr/fr/downloadFile.do?id=5385698&exportType=csv', header=None, delimiter= ';', nrows = 6)

# %%
table.head()
# Out:
#                         0                          1   \
# 0                  Titre :    Dollar australien (AUD)
# 1             Code série :       EXR.D.AUD.EUR.SP00.A
# 2                  Unité :    Dollar Australien (AUD)
# 3              Magnitude :                 Unités (0)
# 4  Méthode d'observation :  Moyenne de la période (A)
#
#                           2                          3   \
# 0          Lev bulgare (BGN)       Real brésilien (BRL)
# 1       EXR.D.BGN.EUR.SP00.A       EXR.D.BRL.EUR.SP00.A
# 2          Lev Nouveau (BGN)       Real Bresilien (BRL)
# 3                 Unités (0)                 Unités (0)
# 4  Moyenne de la période (A)  Moyenne de la période (A)
#
#                           4                          5   \
# 0      Dollar canadien (CAD)         Franc suisse (CHF)
# 1       EXR.D.CAD.EUR.SP00.A       EXR.D.CHF.EUR.SP00.A
# 2      Dollar Canadien (CAD)         Franc Suisse (CHF)
# 3                 Unités (0)                 Unités (0)
# 4  Moyenne de la période (A)  Moyenne de la période (A)
#
#                             6                          7   \
# 0  Yuan renminbi chinois (CNY)      Livre chypriote (CYP)
# 1         EXR.D.CNY.EUR.SP00.A       EXR.D.CYP.EUR.SP00.A
# 2        Yuan Ren Min Bi (CNY)       Livre Cypriote (CYP)
# 3                   Unités (0)                 Unités (0)
# 4    Moyenne de la période (A)  Moyenne de la période (A)
#
#                           8                          9   ...  \
# 0     Couronne tchèque (CZK)     Couronne danoise (DKK)  ...
# 1       EXR.D.CZK.EUR.SP00.A       EXR.D.DKK.EUR.SP00.A  ...
# 2     Couronne Tcheque (CZK)     Couronne Danoise (DKK)  ...
# 3                 Unités (0)                 Unités (0)  ...
# 4  Moyenne de la période (A)  Moyenne de la période (A)  ...
#
#                           30                         31  \
# 0          Leu roumain (RON)         Rouble russe (RUB)
# 1       EXR.D.RON.EUR.SP00.A       EXR.D.RUB.EUR.SP00.A
# 2          Nouveau Ron (RON)   Rouble Russe (RUB) (RUB)
# 3                 Unités (0)                 Unités (0)
# 4  Moyenne de la période (A)  Moyenne de la période (A)
#
#                           32                         33  \
# 0    Couronne suédoise (SEK)  Dollar de Singapour (SGD)
# 1       EXR.D.SEK.EUR.SP00.A       EXR.D.SGD.EUR.SP00.A
# 2    Couronne Suedoise (SEK)  Dollar de Singapour (SGD)
# 3                 Unités (0)                 Unités (0)
# 4  Moyenne de la période (A)  Moyenne de la période (A)
#
#                           34                         35  \
# 0        Tolar slovène (SIT)    Couronne slovaque (SKK)
# 1       EXR.D.SIT.EUR.SP00.A       EXR.D.SKK.EUR.SP00.A
# 2                Tolar (SIT)    Couronne Slovaque (SKK)
# 3                 Unités (0)                 Unités (0)
# 4  Moyenne de la période (A)  Moyenne de la période (A)
#
#                           36                           37  \
# 0     Baht thaïlandais (THB)           Livre turque (TRY)
# 1       EXR.D.THB.EUR.SP00.A         EXR.D.TRY.EUR.SP00.A
# 2                 Baht (THB)  Nouvelle Livre Turque (TRY)
# 3                 Unités (0)                   Unités (0)
# 4  Moyenne de la période (A)    Moyenne de la période (A)
#
#                             38                         39
# 0  Dollar des Etats-Unis (USD)    Rand sud-africain (ZAR)
# 1         EXR.D.USD.EUR.SP00.A       EXR.D.ZAR.EUR.SP00.A
# 2  Dollar des Etats-Unis (USD)                 Rand (ZAR)
# 3                   Unités (0)                 Unités (0)
# 4    Moyenne de la période (A)  Moyenne de la période (A)
#
# [5 rows x 40 columns]

# %%
table = table.T

# %%
table.head()
# Out:
#                          0                     1                        2  \
# 0                  Titre :          Code série :                  Unité :
# 1  Dollar australien (AUD)  EXR.D.AUD.EUR.SP00.A  Dollar Australien (AUD)
# 2        Lev bulgare (BGN)  EXR.D.BGN.EUR.SP00.A        Lev Nouveau (BGN)
# 3     Real brésilien (BRL)  EXR.D.BRL.EUR.SP00.A     Real Bresilien (BRL)
# 4    Dollar canadien (CAD)  EXR.D.CAD.EUR.SP00.A    Dollar Canadien (CAD)
#
#              3                          4  \
# 0  Magnitude :    Méthode d'observation :
# 1   Unités (0)  Moyenne de la période (A)
# 2   Unités (0)  Moyenne de la période (A)
# 3   Unités (0)  Moyenne de la période (A)
# 4   Unités (0)  Moyenne de la période (A)
#
#                                         5
# 0                                Source :
# 1  BCE (Banque Centrale Européenne) (4F0)
# 2  BCE (Banque Centrale Européenne) (4F0)
# 3  BCE (Banque Centrale Européenne) (4F0)
# 4  BCE (Banque Centrale Européenne) (4F0)

# %%
dates = pandas.read_csv('http://webstat.banque-france.fr/fr/downloadFile.do?id=5385698&exportType=csv', header=None, delimiter= ';')

# %%
dates.head(n=10)
# Out:
#                         0                                       1   \
# 0                  Titre :                 Dollar australien (AUD)
# 1             Code série :                    EXR.D.AUD.EUR.SP00.A
# 2                  Unité :                 Dollar Australien (AUD)
# 3              Magnitude :                              Unités (0)
# 4  Méthode d'observation :               Moyenne de la période (A)
# 5                 Source :  BCE (Banque Centrale Européenne) (4F0)
# 6               23/04/2021                                   1,559
# 7               22/04/2021                                  1,5581
# 8               21/04/2021                                  1,5554
# 9               20/04/2021                                  1,5492
#
#                                        2   \
# 0                       Lev bulgare (BGN)
# 1                    EXR.D.BGN.EUR.SP00.A
# 2                       Lev Nouveau (BGN)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                  1,9558
# 7                                  1,9558
# 8                                  1,9558
# 9                                  1,9558
#
#                                        3   \
# 0                    Real brésilien (BRL)
# 1                    EXR.D.BRL.EUR.SP00.A
# 2                    Real Bresilien (BRL)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                  6,5572
# 7                                  6,6546
# 8                                  6,6869
# 9                                  6,7117
#
#                                        4   \
# 0                   Dollar canadien (CAD)
# 1                    EXR.D.CAD.EUR.SP00.A
# 2                   Dollar Canadien (CAD)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                  1,5062
# 7                                  1,5067
# 8                                  1,5137
# 9                                  1,5089
#
#                                        5   \
# 0                      Franc suisse (CHF)
# 1                    EXR.D.CHF.EUR.SP00.A
# 2                      Franc Suisse (CHF)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                  1,1038
# 7                                  1,1035
# 8                                  1,1026
# 9                                  1,1029
#
#                                        6   \
# 0             Yuan renminbi chinois (CNY)
# 1                    EXR.D.CNY.EUR.SP00.A
# 2                   Yuan Ren Min Bi (CNY)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                   7,832
# 7                                  7,8181
# 8                                  7,8011
# 9                                  7,8303
#
#                                        7   \
# 0                   Livre chypriote (CYP)
# 1                    EXR.D.CYP.EUR.SP00.A
# 2                    Livre Cypriote (CYP)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#                                        8   \
# 0                  Couronne tchèque (CZK)
# 1                    EXR.D.CZK.EUR.SP00.A
# 2                  Couronne Tcheque (CZK)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                  25,847
# 7                                   25,86
# 8                                  25,893
# 9                                  25,903
#
#                                        9   ...  \
# 0                  Couronne danoise (DKK)  ...
# 1                    EXR.D.DKK.EUR.SP00.A  ...
# 2                  Couronne Danoise (DKK)  ...
# 3                              Unités (0)  ...
# 4               Moyenne de la période (A)  ...
# 5  BCE (Banque Centrale Européenne) (4F0)  ...
# 6                                  7,4361  ...
# 7                                  7,4366  ...
# 8                                  7,4364  ...
# 9                                  7,4365  ...
#
#                                        30  \
# 0                       Leu roumain (RON)
# 1                    EXR.D.RON.EUR.SP00.A
# 2                       Nouveau Ron (RON)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                  4,9245
# 7                                  4,9274
# 8                                   4,926
# 9                                  4,9278
#
#                                        31  \
# 0                      Rouble russe (RUB)
# 1                    EXR.D.RUB.EUR.SP00.A
# 2                Rouble Russe (RUB) (RUB)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                 90,3287
# 7                                 91,3275
# 8                                 92,0836
# 9                                 92,2786
#
#                                        32  \
# 0                 Couronne suédoise (SEK)
# 1                    EXR.D.SEK.EUR.SP00.A
# 2                 Couronne Suedoise (SEK)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                 10,1405
# 7                                 10,1237
# 8                                 10,1513
# 9                                 10,1288
#
#                                        33  \
# 0               Dollar de Singapour (SGD)
# 1                    EXR.D.SGD.EUR.SP00.A
# 2               Dollar de Singapour (SGD)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                   1,601
# 7                                  1,6001
# 8                                  1,5971
# 9                                  1,6009
#
#                                        34  \
# 0                     Tolar slovène (SIT)
# 1                    EXR.D.SIT.EUR.SP00.A
# 2                             Tolar (SIT)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#                                        35  \
# 0                 Couronne slovaque (SKK)
# 1                    EXR.D.SKK.EUR.SP00.A
# 2                 Couronne Slovaque (SKK)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#                                        36  \
# 0                  Baht thaïlandais (THB)
# 1                    EXR.D.THB.EUR.SP00.A
# 2                              Baht (THB)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                   37,85
# 7                                   37,77
# 8                                  37,666
# 9                                   37,69
#
#                                        37  \
# 0                      Livre turque (TRY)
# 1                    EXR.D.TRY.EUR.SP00.A
# 2             Nouvelle Livre Turque (TRY)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                 10,0635
# 7                                  9,9553
# 8                                  9,8156
# 9                                  9,7764
#
#                                        38  \
# 0             Dollar des Etats-Unis (USD)
# 1                    EXR.D.USD.EUR.SP00.A
# 2             Dollar des Etats-Unis (USD)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                  1,2066
# 7                                  1,2046
# 8                                  1,2007
# 9                                  1,2051
#
#                                        39
# 0                 Rand sud-africain (ZAR)
# 1                    EXR.D.ZAR.EUR.SP00.A
# 2                              Rand (ZAR)
# 3                              Unités (0)
# 4               Moyenne de la période (A)
# 5  BCE (Banque Centrale Européenne) (4F0)
# 6                                 17,2068
# 7                                 17,2348
# 8                                  17,145
# 9                                 17,2287
#
# [10 rows x 40 columns]

# %%
dates = dates.drop([1,2,3,4,5])

# %%
dates.head(10)
# Out:
#             0                        1                  2   \
# 0      Titre :  Dollar australien (AUD)  Lev bulgare (BGN)
# 6   23/04/2021                    1,559             1,9558
# 7   22/04/2021                   1,5581             1,9558
# 8   21/04/2021                   1,5554             1,9558
# 9   20/04/2021                   1,5492             1,9558
# 10  19/04/2021                   1,5491             1,9558
# 11  18/04/2021                        -                  -
# 12  17/04/2021                        -                  -
# 13  16/04/2021                   1,5459             1,9558
# 14  15/04/2021                   1,5448             1,9558
#
#                       3                      4                   5   \
# 0   Real brésilien (BRL)  Dollar canadien (CAD)  Franc suisse (CHF)
# 6                 6,5572                 1,5062              1,1038
# 7                 6,6546                 1,5067              1,1035
# 8                 6,6869                 1,5137              1,1026
# 9                 6,7117                 1,5089              1,1029
# 10                6,7056                 1,5038              1,0998
# 11                     -                      -                   -
# 12                     -                      -                   -
# 13                  6,74                 1,4986              1,1011
# 14                6,7631                 1,4955              1,1046
#
#                              6                      7   \
# 0   Yuan renminbi chinois (CNY)  Livre chypriote (CYP)
# 6                         7,832                    NaN
# 7                        7,8181                    NaN
# 8                        7,8011                    NaN
# 9                        7,8303                    NaN
# 10                       7,8323                    NaN
# 11                            -                    NaN
# 12                            -                    NaN
# 13                       7,8157                    NaN
# 14                       7,8129                    NaN
#
#                         8                       9   ...                 30  \
# 0   Couronne tchèque (CZK)  Couronne danoise (DKK)  ...  Leu roumain (RON)
# 6                   25,847                  7,4361  ...             4,9245
# 7                    25,86                  7,4366  ...             4,9274
# 8                   25,893                  7,4364  ...              4,926
# 9                   25,903                  7,4365  ...             4,9278
# 10                  25,903                  7,4364  ...              4,926
# 11                       -                       -  ...                  -
# 12                       -                       -  ...                  -
# 13                  25,927                  7,4368  ...             4,9263
# 14                  25,942                  7,4372  ...              4,925
#
#                     31                       32                         33  \
# 0   Rouble russe (RUB)  Couronne suédoise (SEK)  Dollar de Singapour (SGD)
# 6              90,3287                  10,1405                      1,601
# 7              91,3275                  10,1237                     1,6001
# 8              92,0836                  10,1513                     1,5971
# 9              92,2786                  10,1288                     1,6009
# 10             91,7527                  10,0985                     1,6014
# 11                   -                        -                          -
# 12                   -                        -                          -
# 13             90,8921                  10,1055                      1,598
# 14             92,2336                  10,1298                     1,5974
#
#                      34                       35                      36  \
# 0   Tolar slovène (SIT)  Couronne slovaque (SKK)  Baht thaïlandais (THB)
# 6                   NaN                      NaN                   37,85
# 7                   NaN                      NaN                   37,77
# 8                   NaN                      NaN                  37,666
# 9                   NaN                      NaN                   37,69
# 10                  NaN                      NaN                  37,589
# 11                  NaN                      NaN                       -
# 12                  NaN                      NaN                       -
# 13                  NaN                      NaN                   37,42
# 14                  NaN                      NaN                  37,376
#
#                     37                           38                       39
# 0   Livre turque (TRY)  Dollar des Etats-Unis (USD)  Rand sud-africain (ZAR)
# 6              10,0635                       1,2066                  17,2068
# 7               9,9553                       1,2046                  17,2348
# 8               9,8156                       1,2007                   17,145
# 9               9,7764                       1,2051                  17,2287
# 10              9,7198                       1,2035                  17,1398
# 11                   -                            -                        -
# 12                   -                            -                        -
# 13              9,6692                       1,1986                  17,0967
# 14              9,7111                        1,197                  17,0453
#
# [10 rows x 40 columns]

# %%
df = pandas.DataFrame(columns=['date','cur'])
for i in dates.columns:
    dates_tmp = dates[dates[i] != '-']
    df['date'] = dates_tmp[0].max()

# %%
df.head(3)
# Out:
# Empty DataFrame
# Columns: [date, cur]
# Index: []

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook
